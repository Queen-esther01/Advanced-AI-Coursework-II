# %%
import pathlib

from dotenv import load_dotenv

from indexing.data_chunker import DataChunker, print_chunk_length_stats
from llm_client import LLMClient
from indexing.vector_store import VectorStore

load_dotenv()
# Out:
# True

# %%
from config import EXTRACTED_MEDIA_DIR, STORE_DIR

data_path = pathlib.Path().cwd() / "data"
disruption_plans_path = data_path / "disruption_plans"
print(pathlib.Path().cwd())
print(f"Store: {STORE_DIR.resolve()}")
# Out:
# /Users/becca/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II
# Store: /Users/becca/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.store

# %%
vector_store = VectorStore()

# %%
print(f"Collection has {vector_store.count()} existing documents")
# Out:
# Collection has 90 existing documents

# %%
llm_client = LLMClient()
chunker = DataChunker(llm_client)
# Out:
# DataChunker ready (store: /Users/becca/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.store)
#   extracted_media: /Users/becca/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.store/extracted_media
#   image cache: /Users/becca/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.store/image_descriptions_cache.json

# %%
# first_data_path = (
#     disruption_plans_path
#     / "SWR Station Disruption Plans/RM Central/Station Disruption Plan - Aldershot Issue 1 - April 2018.docx"
# )

# print("--- Chunking ---")
# chunks = chunker.chunk_file(first_data_path)

# print("\n--- Indexing into Chroma ---")
# n = vector_store.add_chunks(chunks)

# print(f"\nSummary: {n} chunks indexed from {first_data_path.name}")
# print(f"Collection total: {vector_store.count()} documents")

# extracted_files = [p for p in EXTRACTED_MEDIA_DIR.rglob("*") if p.is_file()]
# print(f"Files in .store/extracted_media: {len(extracted_files)}")
# for p in sorted(extracted_files):
#     print(f"  {p.relative_to(STORE_DIR)}")

# %%
first_data_path = (
    disruption_plans_path
    / "20 Batch 2 LOR 2-4 CPT (19th May 21).pptm"
)

print("--- Chunking ---")
chunks = chunker.chunk_file(first_data_path)

print("\n--- Indexing into Chroma ---")
n = vector_store.add_chunks(chunks)

print(f"\nSummary: {n} chunks indexed from {first_data_path.name}")
print(f"Collection total: {vector_store.count()} documents")

extracted_files = [p for p in EXTRACTED_MEDIA_DIR.rglob("*") if p.is_file()]
print(f"Files in .store/extracted_media: {len(extracted_files)}")
for p in sorted(extracted_files):
    print(f"  {p.relative_to(STORE_DIR)}")
# Out:
# --- Chunking ---
# Chunking: 20 Batch 2 LOR 2-4 CPT (19th May 21).pptm
#   Station: 20 Batch 2 LOR 2-4
#   Step 1/3: Reading document...
#   Extracting slide text from 20 Batch 2 LOR 2-4 CPT (19th May 21).pptm...
#   Rendering slides via LibreOffice (150 dpi)...
#   Rendered 45 slides → /Users/becca/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.store/extracted_media/20-batch-2-lor-2-4/slides
#   Step 2/3: Describing slides / images (cache / LLM)...
#   Cache hit: slide-01.jpg (Slide 1: Line Blockage Plans (List View))
#   Cache hit: slide-02.jpg (Slide 2: Woking)
#   Cache hit: slide-03.jpg (Slide 3: Plan 20.1	Woking - Guildford)
#   Cache hit: slide-04.jpg (Slide 4: Plan 20.2	Woking - Guildford)
#   LLM guide: Slide 4: Plan 20.2	Woking - Guildford
#   LLM describing: slide-05.jpg (Slide 5: Guildford)
#   LLM guide: Slide 5: Guildford
#   LLM describing: slide-06.jpg (Slide 6: Plan 21.1	Guildford - Haslemere)
#   LLM guide: Slide 6: Plan 21.1	Guildford - Haslemere
#   LLM describing: slide-07.jpg (Slide 7: Plan 21.2	Guildford - Haslemere)
#   LLM guide: Slide 7: Plan 21.2	Guildford - Haslemere
#   LLM describing: slide-08.jpg (Slide 8: Haslemere)
#   LLM guide: Slide 8: Haslemere
#   LLM describing: slide-09.jpg (Slide 9: Plan 22.1	Haslemere - Petersfield)
#   LLM guide: Slide 9: Plan 22.1	Haslemere - Petersfield
#   LLM describing: slide-10.jpg (Slide 10: Plan 22.2	Haslemere - Petersfield)
#   LLM guide: Slide 10: Plan 22.2	Haslemere - Petersfield
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 7
#       3     / "20 Batch 2 LOR 2-4 CPT (19th May 21).pptm"
#       4 )
#       5
#       6 print("--- Chunking ---")
# ----> 7 chunks = chunker.chunk_file(first_data_path)
#       8
#       9 print("\n--- Indexing into Chroma ---")
#      10 n = vector_store.add_chunks(chunks)
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/indexing/data_chunker.py:464, in DataChunker.chunk_file(self, path, metadata)
#     462 print("  Step 2/3: Describing slides / images (cache / LLM)...")
#     463 if slide_manifest is not None:
# --> 464     image_chunks = self._describe_slides(slide_manifest, station, doc_kind)
#     465     text_chunks = []
#     466     print("  Step 3/3: Slide guides only (no separate raw-text chunks)")
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/indexing/data_chunker.py:402, in DataChunker._describe_slides(self, manifest, station, doc_kind)
#     400 chunks = []
#     401 for entry in manifest:
# --> 402     chunk = self._describe_cpt_slide(entry, station, doc_kind)
#     403     if chunk:
#     404         chunks.append(chunk)
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/indexing/data_chunker.py:359, in DataChunker._describe_cpt_slide(self, entry, station, doc_kind)
#     356     if self.image_cache:
#     357         self.image_cache.set(cache_path, vision_result)
# --> 359 result = self._synthesize_slide_guide(
#     360     section, slide_text, vision_result, doc_kind, cache_path
#     361 )
#     362 chunk_text = _format_slide_guide(section, result)
#     364 metadata = {
#     365     "type": "slide_guide",
#     366     "station": station,
#    (...)    372     "slide_number": n,
#     373 }
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/indexing/data_chunker.py:312, in DataChunker._synthesize_slide_guide(self, section, slide_text, vision_result, doc_kind, cache_path)
#     309     return vision_result
#     311 print(f"  LLM guide: {section}")
# --> 312 guide_result = self.llm_client.generate_slide_guide(
#     313     prompt=slide_guide_prompt(doc_kind),
#     314     section_title=section,
#     315     slide_text=slide_text,
#     316     image_description=vision_result,
#     317 )
#     318 merged = {**vision_result, **guide_result}
#     319 if self.image_cache:
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/llm_client.py:207, in LLMClient.generate_slide_guide(self, prompt, section_title, slide_text, image_description, max_tokens)
#     204     messages = [{"role": "system", "content": self.system_prompt}, *messages]
#     206 with OpenRouter(api_key=self.api_key) as client:
# --> 207     response = client.chat.send(
#     208         model=self.model,
#     209         messages=messages,
#     210         max_tokens=max_tokens,
#     211         response_format={"type": "json_object"},
#     212     )
#     214 raw = _message_content_to_text(response.choices[0].message.content)
#     215 data = _parse_json_response(raw)
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.venv/lib/python3.13/site-packages/openrouter/chat.py:560, in Chat.send(self, messages, http_referer, x_open_router_title, x_open_router_categories, cache_control, debug, frequency_penalty, image_config, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, model, models, parallel_tool_calls, plugins, presence_penalty, provider, reasoning, response_format, seed, service_tier, session_id, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, trace, user, retries, server_url, timeout_ms, http_headers)
#     558 response_data: Any = None
#     559 if utils.match_response(http_res, "200", "application/json"):
# --> 560     http_res_text = utils.stream_to_text(http_res)
#     561     return unmarshal_json_response(
#     562         components.ChatResult, http_res, http_res_text
#     563     )
#     564 if utils.match_response(http_res, "200", "text/event-stream"):
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.venv/lib/python3.13/site-packages/openrouter/utils/serializers.py:201, in stream_to_text(stream)
#     200 def stream_to_text(stream: httpx.Response) -> str:
# --> 201     return "".join(stream.iter_text())
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.venv/lib/python3.13/site-packages/httpx/_models.py:916, in Response.iter_text(self, chunk_size)
#     914 chunker = TextChunker(chunk_size=chunk_size)
#     915 with request_context(request=self._request):
# --> 916     for byte_content in self.iter_bytes():
#     917         text_content = decoder.decode(byte_content)
#     918         for chunk in chunker.decode(text_content):
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.venv/lib/python3.13/site-packages/httpx/_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.venv/lib/python3.13/site-packages/httpx/_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.venv/lib/python3.13/site-packages/httpx/_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Coursework/sem2/ai/cw2/Advanced-AI-Coursework-II/.venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
from pathlib import Path
from IPython.display import Image, display

results = vector_store.query(
    query_texts=["train blockage incident"],
    n_results=5,
)

for i, (doc, meta) in enumerate(zip(results["documents"][0], results["metadatas"][0])):
    print(f"--- Result {i+1} [{meta.get('station')} / {meta.get('section')}] ---")
    #print meta keys
    # print(meta.keys())
    # dict_keys(['filename', 'image_type', 'source_image', 'type', 'section', 'source', 'caption', 'slide_number', 'blocked_section', 'image_path', 'document_type', 'stations_or_junctions', 'station'])

    print(doc)
    # print(doc[:400])
    # doc_type = meta.get("type")
    # image_type = meta.get("image_type")
    # source_image = meta.get("source_image")
    # caption = meta.get("caption")
    # slide_number = meta.get("slide_number")
    # blocked_section = meta.get("blocked_section")
    # stations_or_junctions = meta.get("stations_or_junctions")
    # station = meta.get("station")
    # document_type = meta.get("document_type")
    # filename = meta.get("filename")
    # section = meta.get("section")
    # print(f"Document type: {doc_type}")
    # print(f"Image type: {image_type}")
    # print(f"Source image: {source_image}")
    # print(f"Caption: {caption}")
    # print(f"Slide number: {slide_number}")
    # print(f"Blocked section: {blocked_section}")
    # print(f"Stations or junctions: {stations_or_junctions}")
    # print(f"Station: {station}")
    # print(f"Document type: {document_type}")
    # print(f"Filename: {filename}")
    # print(f"Section: {section}")
    # image_path = meta.get("image_path")
    # if image_path and Path(image_path).exists():
    #     print(f"Image: {image_path}")
    #     display(Image(filename=image_path))
    
   
    print()
# Out:
# --- Result 1 [20 Batch 2 LOR 2-4 / Slide 43: Plan 32.1	Farnham - Bentley] ---
# [Image: plan-32-1-farnham-bentley-slide.json] Slide 43, Plan 32.1 for Farnham to Bentley, shows a line blockage on the Alton Line with alternative passenger journeys via bus. This slide presents contingency information for a line blockage between Farnham and Bentley on the Alton Line. The top left shows the plan name and status (Line blocked). Below this is text detailing principles of service alteration, alternative passenger journeys involving bus replacements, information for signallers to terminate services at Farnham, and additional information for station staff. A track schematic on the top-middle shows the line from Frimley and Woking south to Bentley and Alton, with a red blocked line indicated between Farnham and Bentley. A network map of the wider South Western Railway region appears on the right. The bottom of the slide contains useful contact details for various stations along the route.
#
# --- Result 2 [20 Batch 2 LOR 2-4 / Slide 29: Plan 35.1	Andover - Laverstock North Junction] ---
# [Image: plan-35-1-andover-laverstock-north-junction-slide.png] Plan 35.1 details Andover to Laverstock North Junction service changes during a complete blockage. This slide is a contingency plan (35.1) for Andover to Laverstock North Junction, showing service alterations during a blockage. The upper left shows the plan title and status ('Both lines blocked'), along with text detailing service alterations for off-peak and peak times. There's information for signallers and station staff. A network map (top right) shows the wider rail network and a track schematic (centre) highlights the affected area with red lines, indicating the blocked sections. Useful contact details for stations are given in a colour-coded table along the bottom, including IDs for Andover, Grateley, Whitchurch, Salisbury, Basingstoke and Overton. Navigation buttons from the Contingency Planning document are visible along the right side.
#
# --- Result 3 [20 Batch 2 LOR 2-4 / Slide 27: Plan 34.2	Basingstoke - Andover] ---
# [Image: plan-34-2-basingstoke-andover-slide.json] Plan 34.2 details rail service alterations for a blocked line between Basingstoke and Andover. This slide presents contingency plans for a line blockage between Basingstoke and Andover, featuring a combination of text, a track schematic, and a broader network map. The left side of the slide contains the plan's title, status, and principles of service alteration for both peak and off-peak times. It describes alternative passenger journeys and information for both Signallers and station staff, closing with passenger information about local bus routes. A regional track diagram shows the railway lines from Salisbury to Reading, highlighting the section between Andover and Worting Junction as a blocked line. An adjacent network map offers a wider geographical context, showing connections to London and other regions.
#
# --- Result 4 [20 Batch 2 LOR 2-4 / Slide 10: Plan 22.2	Haslemere - Petersfield] ---
# [Image: cpt-plan-22.2-haslemere-petersfield-slide.json] Plan 22.2 outlines service alterations for the Haslemere - Petersfield segment of the Portsmouth Direct line due to a blockage. This slide details contingency plans for a line blockage between Haslemere and Petersfield; 'Plan 22.2 Haslemere - Petersfield' is stated at the top left. The slide is divided into several sections: a status box indicating 'One line blocked (in either direction)', principles of service alteration for off-peak and peak times (describing train diversions and terminations), alternative passenger journeys (bus replacement services), information for signallers, additional information for station staff, and passenger information. A schematic diagram in the upper middle highlights the line between Witley and Havant (Junction), with the segment from Haslemere to Petersfield shown as blocked in red. A regional, non-geographic map on the right depicts a wider network, and a table below provides useful contact details and station information for this line of route.
#
# --- Result 5 [20 Batch 2 LOR 2-4 / Slide 20: Plan 26.1	Fratton - Portsmouth & Southsea] ---
# [Image: plan-26-1-fratton-portsmouth-southsea-slide.json] Plan 26.1 shows service alterations for a complete blockade between Fratton and Portsmouth & Southsea stations. This slide details contingency plans for a line blockage between Fratton and Portsmouth & Southsea. The slide is divided into sections: the plan title and status at the top-left, followed by "Principles of Service Alteration" for various train operators (SWR, GTR, GWR). A track schematic displays the Portsmouth Direct line from Fareham to Portsmouth Harbour with a red blocked section between Fratton and Portsmouth & Southsea. A network map shows the wider rail network, and a table at the bottom lists useful contact details and station codes. Text provides information for signallers, station staff and passengers, including bus replacement services.

# %%
chunked = chunker.chunk_directory(disruption_plans_path)
all_chunks = [chunk for chunks in chunked.values() for chunk in chunks]
n = vector_store.add_chunks(all_chunks)
print(f"\nIndexed {n} chunks across {len(chunked)} files")
print(f"Collection now has {vector_store.count()} documents")

# %%
from pathlib import Path
from IPython.display import Image, display

results = vector_store.query(
    query_texts=["Aldershot station incident"],
    n_results=5,
)

for i, (doc, meta) in enumerate(zip(results["documents"][0], results["metadatas"][0])):
    print(f"--- Result {i+1} [{meta.get('station')} / {meta.get('section')}] ---")
    print(doc[:400])
    image_path = meta.get("image_path")
    if image_path and Path(image_path).exists():
        print(f"Image: {image_path}")
        display(Image(filename=image_path))
    print()
